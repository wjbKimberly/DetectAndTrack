# %%
import numpy as np
import json
import os
from matplotlib import pyplot as plt
import matplotlib.image as mpimg


def get_test_heatmap(image_heatmap_json_file_path):
    print("******************* get_test_heatmap start *******************")
    if not os.path.exists(image_heatmap_json_file_path):
        print("******* the file <"+image_heatmap_json_file_path+"> is not exists!*******\n")
    print("load file <"+image_heatmap_json_file_path+"> heatmap data!")
    
    heatmaps_all_one_image=[]
    
    
    with open(image_heatmap_json_file_path) as data_file:
        data=json.load(data_file)
        
    image_name=data["image_name"]
    detect_bbox=data["detect"]
    kps=data["keypoints"]
    
    #find keypoints
    for pidx in range(len(kps)):
        
    print(np.asarray(kps).shape)
    print(kps[0])
    
    
    #find heatmaps
    heatmaps=data["heatmaps"]
    heatmaps_np=np.asarray(heatmaps)
    print("\nthe heatmaps shape in one image:",heatmaps_np.shape)
    for personidx in range(len(heatmaps)):
        for heatmapidx in range(len(heatmaps[personidx])):
            heatmap=heatmaps[personidx][heatmapidx]
            heatmaps_all_one_image.append(heatmap)
            
    print("the numbers of heatmaps in one image: ",len(heatmaps_all_one_image))

    print("******************* get_test_heatmap end *******************")
    return image_name,heatmaps_all_one_image




def visualize_one_heatmap(heatmap):
    print("******************* visualize_one_heatmap start *******************")
    print("the shape of heatmap: ",np.asarray(heatmap).shape)
    figure=plt.figure()
    plt.imshow(heatmap)

    
    
    
    
    
image_json_file_root="/var/storage/shared/pnrsy/t-jiwan/DetectAndTrack-wjb/tools/show_results/01_R101_best_hungarian-4GPU.yaml_nms=0.500000_score=_0.050000_drop_low_conf=0.950000/image_file/"
image_origin_root="/var/storage/shared/pnrsy/t-jiwan/DetectAndTrack-wjb/"
file_name="images\\bonn_5sec\\000342_mpii\\00000064.jpg.json"
image_name,heatmaps=get_test_heatmap(image_json_file_root+file_name)
img=mpimg.imread(image_origin_root+image_name)
print(img.shape)
plt.imshow(img)

visualize_one_heatmap(heatmaps[0])
# Out:
# ******************* get_test_heatmap start *******************
# load file </var/storage/shared/pnrsy/t-jiwan/DetectAndTrack-wjb/tools/show_results/01_R101_best_hungarian-4GPU.yaml_nms=0.500000_score=_0.050000_drop_low_conf=0.950000/image_file/images\bonn_5sec\000342_mpii\00000064.jpg.json> heatmap data!
# (2, 5, 17)
# [[589.3204956054688, 550.37451171875, 592.3163452148438, 590.319091796875, 552.3717651367188, 600.3052368164062, 521.4147338867188, 632.2608642578125, 522.413330078125, 662.2192993164062, 650.2359619140625, 450.51312255859375, 409.5699462890625, 276.7542724609375, 297.72515869140625, 205.85267639160156, 164.9095001220703], [135.59727478027344, 152.53787231445312, 98.72653198242188, 131.61123657226562, 111.68111419677734, 171.47149658203125, 151.54136657714844, 234.25140380859375, 185.42259216308594, 263.15008544921875, 259.1640625, 247.2059783935547, 205.35272216796875, 263.15008544921875, 222.29331970214844, 209.3387451171875, 268.13262939453125], [7.157739639282227, 7.509038925170898, 0.3230404853820801, -0.8172752857208252, 6.588849067687988, 2.673717737197876, 4.8951029777526855, 1.6538128852844238, -0.601517915725708, 2.010298252105713, 0.373308390378952, 5.960865020751953, 10.583367347717285, 6.290154933929443, 12.806132316589355, 2.1110312938690186, 6.41555643081665], [0.017975224182009697, 0.0036766265984624624, 0.003154110163450241, 0.0013968985294923186, 0.005754935555160046, 0.0012964585330337286, 0.0018493469106033444, 0.0006225708639249206, 0.0004566775751300156, 0.0012843174627050757, 0.0009846523171290755, 0.002023671753704548, 0.0029739835299551487, 0.004278665408492088, 0.005360075272619724, 0.002238154411315918, 0.00461955089122057], [0.0, 1.0, -1.0, -1.0, 4.0, -1.0, 6.0, -1.0, -1.0, -1.0, -1.0, 11.0, 12.0, 13.0, 14.0, -1.0, 16.0]]
#
# the heatmaps shape in one image: (2, 17, 56, 56)
# the numbers of heatmaps in one image:  34
# ******************* get_test_heatmap end *******************
# (480, 854, 3)
# ******************* visualize_one_heatmap start *******************
# the shape of heatmap:  (56, 56)

# %%
# Out:
# The following command must be run outside of the IPython shell:
#
#     $ pip list
#
# The Python package manager (pip) can only be used from outside of IPython.
# Please reissue the `pip` command in a separate terminal or command prompt.
#
# See the Python documentation for more information on how to install packages:
#
#     https://docs.python.org/3/installing/
